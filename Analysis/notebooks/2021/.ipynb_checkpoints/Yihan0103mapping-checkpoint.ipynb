# %%
import sys
sys.path.append('/home/ardelalegre/SoundMapping/Analysis/Util')
sys.path.append('/home/ardelalegre/SoundMapping/Database')
from DatabaseAPI import DatabaseAPI
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from get_time_interval_data import *
from PCA import *
from Plot import *
import pickle
from sklearn.cluster import KMeans

# %%
# clean out NaNs and zeros
def extract_all_active_observations_v2(interval_matrix_data, array_indices):
    # exclude time column
    observations = interval_matrix_data[:,1:]
    selected_obs = np.hstack([observations[:,i*3:i*3+3] for i in array_indices])
    cleaned_data = []
    ind = []
    for i in range(selected_obs.shape[0]):
        if not any(np.isnan(selected_obs[i,:])) and not any(selected_obs[i,:]==0):
            cleaned_data.append(selected_obs[i,:])
            ind.append(i)
    selected_raw_obs = interval_matrix_data[ind,:]        
    return  np.vstack(cleaned_data), selected_raw_obs

# %%
def plot_time_series(data):
    # only plotting x
    length = data.shape[0]
    fig = plt.figure(figsize = [20,10])
    ax1 = fig.add_subplot(511)
    ax1.plot(data[:,1], label='array 0')  # array 0
    ax1.set_xlim(0,length)
    ax1.set_ylim(-1,1)
    ax1.legend()
    ax2 = fig.add_subplot(512)
    ax2.plot(data[:,4], label='array 1')  # array 1
    ax2.set_xlim(0,length)
    ax2.set_ylim(-1,1)
    ax2.legend()
    ax3 = fig.add_subplot(513)
    ax3.plot(data[:,7], label='array 2')  # array 2
    ax3.set_xlim(0,length)
    ax3.set_ylim(-1,1)
    ax3.legend()  
    ax4 = fig.add_subplot(514)
    ax4.plot(data[:,10], label='array 3') # array 3
    ax4.set_xlim(0,length)
    ax4.set_ylim(-1,1)
    ax4.legend()
    ax5 = fig.add_subplot(515)
    ax5.plot(data[:,16], label='array 5') # array 5
    ax5.set_xlim(0,length)
    ax5.set_ylim(-1.,1.)
    ax5.legend()
    plt.xlabel('Time (samples)',fontsize='x-large')
    plt.show()

# %% [markdown]
# ## note
# Two arrays are mounted onto the wall: array 0 and 1, and array 2, 3, 5 are mounted to the ceiling.

# %%
#for I=1:4
    
#if (I==1)
standard = get_time_interval_matrix_data("Dec 24 2020 11:56AM", "Dec 24 2020 12:00PM") # E-W x-axis?
#elseif (I==2)
#####standard = get_time_interval_matrix_data("Dec 24 2020 01:11PM", "Dec 24 2020 01:15PM") # NS y-axis?
#standard = get_time_interval_matrix_data("Dec 24 2020 01:15PM", "Dec 24 2020 01:19PM") # NS y-axis?
#test = get_time_interval_matrix_data("Dec 23 2020 03:40PM", "Dec 23 2020 03:45PM")
#standard = get_time_interval_matrix_data("Dec 30 2020 03:55PM", "Dec 30 2020 03:56PM") #Move from chair2to1
#standard = get_time_interval_matrix_data("Dec 30 2020 03:02PM", "Dec 30 2020 03:05PM") #arc

# %%
plot_time_series(standard)

# %%
#plot_time_series(test)

# %%
#standard_cleaned, standard_og = extract_all_active_observations_v2(standard, [1, 2,3,5])
standard_cleaned, standard_og = extract_all_active_observations_v2(standard, [0,1,2,3,5])
#standard_cleaned, standard_og = extract_all_active_observations_v2(standard, [2,3,5])

# %%
standard_og[1:7,:] = np.NaN
#standard_og[1:4,:] = np.NaN
standard_cdata = get_cdata(standard_og)
projections_standard = project_to_eigen_vectors(standard_cdata, 2, EIGEN_VALUES_0819, EIGEN_VECTORS_0819)
standard_cdata.shape
# Out:
# /home/ardelalegre/SoundMapping/Analysis/Util/PCA.py:43: RuntimeWarning: Mean of empty slice
#   data_mean = np.nanmean(data[:,1:],axis = 0,keepdims = True)
# (2087, 18)

# %%
fig = plt.figure(figsize = [20,10])

ax1 = fig.add_subplot(121)
room_model_chair = plt.imread('room_model_v4.png')
ax1.imshow(room_model_chair)
# ax2.invert_xaxis()

ax = fig.add_subplot(122)
temp = ax.scatter(projections_standard[:,0], 
                  projections_standard[:,1], 
                  c = np.arange(projections_standard.shape[0]), 
                  s=0.1)
ax.set_xlim(-1,1)
ax.set_ylim(-1,1)
#ax.invert_xaxis()
#ax.invert_yaxis()
cbar = fig.colorbar(temp, ax=ax)
cbar.ax.set_title('Index')

plt.show()

# %% [markdown]
# ## mapping

# %%
# creating R
RChairs = np.transpose(np.array([[1.266, 2.685], [0.450, 0.791], [2.598, 1.567], [3.544, 1.523], [3.040, 3.120]]))

B = pickle.load(open('B.p','rb'))

#CHAIR 1:
DobsPoint = pickle.load(open('D1.p','rb'))
RobsPoint = np.array([[1.266], [2.685]]) #as specified
#CHAIR 2:
DobsPoint = pickle.load(open('D2.p','rb'))
RobsPoint = np.array([[0.450], [0.791]])

# %%
Dused=standard_cleaned

Dused=np.transpose(np.array(Dused))

Dtest=(Dused-DobsPoint.reshape(len(DobsPoint),1))
rvec=RobsPoint +B@(Dtest)

# %%
fig = plt.figure(figsize = [20,10])

# ax1 = fig.add_subplot(121)
# room_model_chair = plt.imread('room_model_v4.png')
# ax1.imshow(room_model_chair)
# # ax2.invert_xaxis()
# # 
ax = fig.add_subplot(111)
temp = ax.scatter(rvec[0,:], rvec[1,:], c = np.arange(projections_standard.shape[0]),        s=0.1)
ax.set_xlim(-0,4.385)
ax.set_ylim(-0,3.918)
#ax.invert_xaxis()
#ax.invert_yaxis()
cbar = fig.colorbar(temp, ax=ax)
cbar.ax.set_title('Index')
# ax.scatter(RobsPoint[0,0], RobsPoint[1,0], c = 'r', s = 10, label = 'Original Positions')
ax.scatter(RChairs[0,:], RChairs[1,:], c = 'r', s = 10, label = 'Original Positions')
#plt.text(RChairs[0,:], RChairs[1,:],["1" "2" "3" "4" "5"] )

marker_list = ["$1$","$2$","$3$","$4$","$5$"]
for i in range(RChairs.shape[1]):
    plt.scatter(RChairs[0,i]+0.1, RChairs[1,i],marker=marker_list[i] , s=100, c = 'r')

# plt.text(RChairs[0,0], RChairs[1,0],["1"] ),plt.text(RChairs[0,1], RChairs[1,1],["2"] ,fontsize='x-large')
# plt.text(RChairs[0,2], RChairs[1,2],["3"] ),plt.text(RChairs[0,3], RChairs[1,3],["4"] ,fontsize='x-large')
# plt.text(RChairs[0,4], RChairs[1,4],["5"],fontsize='x-large')
plt.xlabel('EW direction',fontsize='x-large')
plt.ylabel('NS direction',fontsize='x-large')
#plt.savefig('Experimnt30dec2to1ref1.pdf')
#plt.savefig('Experimnt30decArc.pdf')
plt.savefig('Experimnt24decNS.pdf')
#plt.savefig('Experimnt24decEW.pdf')
plt.show()

# %%
# fig = plt.figure(figsize = [20,10])

# ax1 = fig.add_subplot(121)
# temp = ax1.scatter(rvec[0,:], rvec[1,:], c = np.arange(projections_standard.shape[0]),        s=0.1)
# ax1.set_xlim(-0,4.385)
# ax1.set_ylim(-0,3.918)
# #ax.invert_xaxis()
# #ax.invert_yaxis()
# cbar = fig.colorbar(temp, ax=ax1)
# cbar.ax.set_title('Index')
# ax1.scatter(RobsPoint[0,0], RobsPoint[1,0], c = 'r', s = 10, label = 'Original Positions')
# ax1.scatter(RChairs[0,:], RChairs[1,:], c = 'r', s = 10, label = 'Original Positions')
# #plt.text(RChairs[0,:], RChairs[1,:],["1" "2" "3" "4" "5"] )
# #plt.scatter(RChairs[0,:], RChairs[1,:],["1" "2" "3" "4] )
# plt.text(RChairs[0,0], RChairs[1,0],["1"] ),plt.text(RChairs[0,1], RChairs[1,1],["2"] ,fontsize='x-large')
# plt.text(RChairs[0,2], RChairs[1,2],["3"] ),plt.text(RChairs[0,3], RChairs[1,3],["4"] ,fontsize='x-large')
# plt.text(RChairs[0,4], RChairs[1,4],["5"],fontsize='x-large')
# plt.xlabel('EW direction',fontsize='x-large')
# plt.ylabel('NS direction',fontsize='x-large')

# # room_model_chair = plt.imread('room_model_v4.png')
# # ax1.imshow(room_model_chair)
# # # ax2.invert_xaxis()
# # # 
# #CHAIR 1:
# DobsPoint = pickle.load(open('D1.p','rb'))
# RobsPoint = np.array([[1.266], [2.685]]) #as specified
# Dtest=(Dused-DobsPoint.reshape(len(DobsPoint),1))
# rvec1=RobsPoint +B@(Dtest)
# #CHAIR 2:
# DobsPoint = pickle.load(open('D2.p','rb'))
# RobsPoint = np.array([[0.450], [0.791]])
# Dtest=(Dused-DobsPoint.reshape(len(DobsPoint),1))
# rvec2=RobsPoint +B@(Dtest)
# rdiff=rvec1-rvec2
# rsum=np.sum(rdiff)
# ax = fig.add_subplot(122)
# temp = ax.scatter(rdiff[0,:], rdiff[1,:], c = np.arange(projections_standard.shape[0]),        s=10)
# ax.set_xlim(-.1,.1)
# ax.set_ylim(-.1,.1)
# #ax.invert_xaxis()
# #ax.invert_yaxis()
# cbar = fig.colorbar(temp, ax=ax)
# cbar.ax.set_title('Index')
# # ax.scatter(RobsPoint[0,0], RobsPoint[1,0], c = 'r', s = 10, label = 'Original Positions')
# # ax.scatter(RChairs[0,:], RChairs[1,:], c = 'r', s = 10, label = 'Original Positions')
# # #plt.text(RChairs[0,:], RChairs[1,:],["1" "2" "3" "4" "5"] )
# # plt.text(RChairs[0,0], RChairs[1,0],["1"] ),plt.text(RChairs[0,1], RChairs[1,1],["2"] ,fontsize='x-large')
# # plt.text(RChairs[0,2], RChairs[1,2],["3"] ),plt.text(RChairs[0,3], RChairs[1,3],["4"] ,fontsize='x-large')
# # plt.text(RChairs[0,4], RChairs[1,4],["5"],fontsize='x-large')
# # plt.xlabel('EW direction',fontsize='x-large')
# # plt.ylabel('NS direction',fontsize='x-large')

# plt.show()
# print(rdiff)
